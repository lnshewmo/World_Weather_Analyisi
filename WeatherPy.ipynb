# %% [markdown]
# # WeatherPy

# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# import the requests library
import requests
# import the API key
from config import weather_api_key

# %%
# create a set of random lat long combos
lats = np.random.uniform(low=-90,high=90, size =1500)
longs = np.random.uniform(-180,180, 1500)
lat_longs= zip(lats, longs)
lat_longs

# ouput is an array of tuples with indicies

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_longs)

#You can only unzip a zipped tuple once before it is removed from the computer's memory. 
#Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.
# Use the print() function to display the latitude and longitude combinations

# uncomment the for loop to visually confirm the coordinate list
#for coordinate in coordinates:
   # print(coordinate[0], coordinate[1])

# %%
# create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, add to the cities list
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient quantity
len(cities)
# Out:
# 627

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
# initialized the counters at 1 bc we want to start both at 1
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in our list.
# for i in range(len(cities)) # THIS WON'T DO BC NEED CITY NAME NOT INDEX IN URL
# create the for loop with the enumerate() method and reference the index and the city in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    # tell program to pause 60 sec bc the API oly allows 60 calls per min for free
    # prevents time out errors
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    # city_url = url + "&q=" + cities[i]  # THIS URL WONT WORK BC NEED CITY NAME
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count 
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        # pass handles all errors and allows to continue
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | matinhos
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | oranjemund
# Processing Record 5 of Set 1 | nanortalik
# Processing Record 6 of Set 1 | teguise
# Processing Record 7 of Set 1 | rawson
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | monteagudo
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | sarakhs
# Processing Record 20 of Set 1 | gat
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | belen
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | palora
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | ornskoldsvik
# Processing Record 28 of Set 1 | padang
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | pangody
# Processing Record 32 of Set 1 | chokurdakh
# Processing Record 33 of Set 1 | iwaki
# Processing Record 34 of Set 1 | nome
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | ajdabiya
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | saint george
# Processing Record 40 of Set 1 | namibe
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | mirpur khas
# Processing Record 43 of Set 1 | suntar
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | bambous virieux
# Processing Record 46 of Set 1 | nemuro
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | yar-sale
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | lavrentiya
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | poum
# Processing Record 8 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | cassilandia
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 2 | ahuimanu
# Processing Record 16 of Set 2 | korla
# Processing Record 17 of Set 2 | trindade
# Processing Record 18 of Set 2 | kahului
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | salalah
# Processing Record 24 of Set 2 | arenapolis
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | waipawa
# Processing Record 27 of Set 2 | luino
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | weligama
# Processing Record 31 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 32 of Set 2 | nuuk
# Processing Record 33 of Set 2 | kieta
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | baykit
# Processing Record 37 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 2 | aswan
# Processing Record 39 of Set 2 | airai
# Processing Record 40 of Set 2 | acarau
# Processing Record 41 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | thompson
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | souillac
# Processing Record 48 of Set 2 | atasu
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | vestmannaeyjar
# Processing Record 1 of Set 3 | najran
# Processing Record 2 of Set 3 | cartagena del chaira
# Processing Record 3 of Set 3 | verkhnyaya inta
# Processing Record 4 of Set 3 | porto novo
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | santa rosa
# Processing Record 7 of Set 3 | broken hill
# Processing Record 8 of Set 3 | broome
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | iquique
# Processing Record 11 of Set 3 | yakeshi
# Processing Record 12 of Set 3 | hongjiang
# Processing Record 13 of Set 3 | freeport
# Processing Record 14 of Set 3 | eskil
# Processing Record 15 of Set 3 | los llanos de aridane
# Processing Record 16 of Set 3 | yerbogachen
# Processing Record 17 of Set 3 | noumea
# Processing Record 18 of Set 3 | altrincham
# Processing Record 19 of Set 3 | kruisfontein
# Processing Record 20 of Set 3 | ukiah
# Processing Record 21 of Set 3 | marzuq
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | imperia
# Processing Record 24 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 3 | xining
# Processing Record 26 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | golfito
# Processing Record 29 of Set 3 | altamira
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | calabozo
# Processing Record 32 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 3 | aktau
# Processing Record 34 of Set 3 | minggang
# Processing Record 35 of Set 3 | saint-georges
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | severo-kurilsk
# Processing Record 39 of Set 3 | ola
# Processing Record 40 of Set 3 | lasa
# Processing Record 41 of Set 3 | forbes
# Processing Record 42 of Set 3 | shahpur
# Processing Record 43 of Set 3 | ode
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | umm lajj
# Processing Record 46 of Set 3 | san patricio
# Processing Record 47 of Set 3 | mut
# Processing Record 48 of Set 3 | alta floresta
# Processing Record 49 of Set 3 | nacala
# Processing Record 50 of Set 3 | mount gambier
# Processing Record 1 of Set 4 | houma
# Processing Record 2 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | parana
# Processing Record 6 of Set 4 | inhambane
# Processing Record 7 of Set 4 | samarai
# Processing Record 8 of Set 4 | kalmar
# Processing Record 9 of Set 4 | longyearbyen
# Processing Record 10 of Set 4 | butaritari
# Processing Record 11 of Set 4 | vaitape
# Processing Record 12 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 4 | lebu
# Processing Record 14 of Set 4 | luanda
# Processing Record 15 of Set 4 | maturin
# Processing Record 16 of Set 4 | sosnovo-ozerskoye
# Processing Record 17 of Set 4 | rocha
# Processing Record 18 of Set 4 | lanzhou
# Processing Record 19 of Set 4 | great falls
# Processing Record 20 of Set 4 | huarmey
# Processing Record 21 of Set 4 | port augusta
# Processing Record 22 of Set 4 | pauini
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | sao felix do xingu
# Processing Record 25 of Set 4 | esmeralda
# Processing Record 26 of Set 4 | rio gallegos
# Processing Record 27 of Set 4 | moree
# Processing Record 28 of Set 4 | adrar
# Processing Record 29 of Set 4 | la union
# Processing Record 30 of Set 4 | cape town
# Processing Record 31 of Set 4 | trairi
# Processing Record 32 of Set 4 | sao joao da barra
# Processing Record 33 of Set 4 | mahibadhoo
# Processing Record 34 of Set 4 | urumqi
# Processing Record 35 of Set 4 | paranhos
# Processing Record 36 of Set 4 | taitung
# Processing Record 37 of Set 4 | waitati
# Processing Record 38 of Set 4 | tala
# Processing Record 39 of Set 4 | macamic
# Processing Record 40 of Set 4 | rassvet
# Processing Record 41 of Set 4 | san pedro de ycuamandiyu
# Processing Record 42 of Set 4 | merritt island
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | ahipara
# Processing Record 45 of Set 4 | sawakin
# Processing Record 46 of Set 4 | youghal
# Processing Record 47 of Set 4 | leshukonskoye
# Processing Record 48 of Set 4 | praia da vitoria
# Processing Record 49 of Set 4 | lundazi
# Processing Record 50 of Set 4 | miandrivazo
# Processing Record 1 of Set 5 | albury
# Processing Record 2 of Set 5 | sinnamary
# Processing Record 3 of Set 5 | kikwit
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | namatanai
# Processing Record 6 of Set 5 | chenzhou
# Processing Record 7 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 8 of Set 5 | cumana
# Processing Record 9 of Set 5 | miri
# Processing Record 10 of Set 5 | aripuana
# Processing Record 11 of Set 5 | abu kamal
# Processing Record 12 of Set 5 | karachi
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | riohacha
# Processing Record 15 of Set 5 | fort nelson
# Processing Record 16 of Set 5 | uttaradit
# Processing Record 17 of Set 5 | ostrovnoy
# Processing Record 18 of Set 5 | muskogee
# Processing Record 19 of Set 5 | vazante
# Processing Record 20 of Set 5 | raga
# Processing Record 21 of Set 5 | dalby
# Processing Record 22 of Set 5 | anadyr
# Processing Record 23 of Set 5 | alofi
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | victoria
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | maceio
# Processing Record 28 of Set 5 | palaiokhora
# City not found. Skipping...
# Processing Record 29 of Set 5 | douglas
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | fort morgan
# Processing Record 32 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 5 | fairbanks
# Processing Record 34 of Set 5 | praia
# Processing Record 35 of Set 5 | cairns
# Processing Record 36 of Set 5 | dalvik
# Processing Record 37 of Set 5 | price
# Processing Record 38 of Set 5 | lichinga
# Processing Record 39 of Set 5 | zaraysk
# Processing Record 40 of Set 5 | hobyo
# Processing Record 41 of Set 5 | rayong
# Processing Record 42 of Set 5 | kichera
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | panguna
# Processing Record 45 of Set 5 | upernavik
# Processing Record 46 of Set 5 | antofagasta
# Processing Record 47 of Set 5 | tepeji
# City not found. Skipping...
# Processing Record 48 of Set 5 | makaha
# Processing Record 49 of Set 5 | fuerte olimpo
# Processing Record 50 of Set 5 | shubarshi
# Processing Record 1 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | nizhniy kuranakh
# Processing Record 4 of Set 6 | shemonaikha
# Processing Record 5 of Set 6 | tautira
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | havre-saint-pierre
# Processing Record 8 of Set 6 | bonavista
# Processing Record 9 of Set 6 | kihei
# Processing Record 10 of Set 6 | anloga
# Processing Record 11 of Set 6 | bezhetsk
# Processing Record 12 of Set 6 | nouadhibou
# Processing Record 13 of Set 6 | khanpur
# Processing Record 14 of Set 6 | birobidzhan
# Processing Record 15 of Set 6 | zhigansk
# Processing Record 16 of Set 6 | takoradi
# Processing Record 17 of Set 6 | chegdomyn
# Processing Record 18 of Set 6 | flin flon
# Processing Record 19 of Set 6 | tubuala
# Processing Record 20 of Set 6 | ust-nera
# Processing Record 21 of Set 6 | naryan-mar
# Processing Record 22 of Set 6 | augustow
# Processing Record 23 of Set 6 | hickory
# Processing Record 24 of Set 6 | avarua
# Processing Record 25 of Set 6 | bandon
# Processing Record 26 of Set 6 | ilheus
# Processing Record 27 of Set 6 | nikolskoye
# Processing Record 28 of Set 6 | tabou
# Processing Record 29 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 6 | bol
# Processing Record 31 of Set 6 | cidreira
# Processing Record 32 of Set 6 | begunitsy
# Processing Record 33 of Set 6 | umba
# Processing Record 34 of Set 6 | dehloran
# Processing Record 35 of Set 6 | egvekinot
# Processing Record 36 of Set 6 | solnechnyy
# Processing Record 37 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 6 | loandjili
# Processing Record 39 of Set 6 | las margaritas
# Processing Record 40 of Set 6 | santa rosa de aguan
# Processing Record 41 of Set 6 | vao
# Processing Record 42 of Set 6 | taltal
# Processing Record 43 of Set 6 | graaff-reinet
# Processing Record 44 of Set 6 | omboue
# Processing Record 45 of Set 6 | tondano
# Processing Record 46 of Set 6 | sultanpur
# Processing Record 47 of Set 6 | luangwa
# Processing Record 48 of Set 6 | yumen
# Processing Record 49 of Set 6 | ampanihy
# Processing Record 50 of Set 6 | batagay
# Processing Record 1 of Set 7 | woodward
# Processing Record 2 of Set 7 | eyrarbakki
# Processing Record 3 of Set 7 | kota belud
# Processing Record 4 of Set 7 | kjopsvik
# Processing Record 5 of Set 7 | san andres
# Processing Record 6 of Set 7 | port blair
# Processing Record 7 of Set 7 | tirumullaivasal
# Processing Record 8 of Set 7 | weyburn
# Processing Record 9 of Set 7 | college
# Processing Record 10 of Set 7 | margate
# Processing Record 11 of Set 7 | tura
# Processing Record 12 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 13 of Set 7 | lucapa
# Processing Record 14 of Set 7 | seymchan
# Processing Record 15 of Set 7 | amahai
# Processing Record 16 of Set 7 | nantucket
# Processing Record 17 of Set 7 | rio grande
# Processing Record 18 of Set 7 | sao miguel do araguaia
# Processing Record 19 of Set 7 | rockledge
# Processing Record 20 of Set 7 | kharp
# Processing Record 21 of Set 7 | eureka
# Processing Record 22 of Set 7 | portland
# Processing Record 23 of Set 7 | jalu
# Processing Record 24 of Set 7 | yurino
# Processing Record 25 of Set 7 | skjervoy
# Processing Record 26 of Set 7 | chara
# Processing Record 27 of Set 7 | bafq
# Processing Record 28 of Set 7 | aklavik
# Processing Record 29 of Set 7 | bacolod
# Processing Record 30 of Set 7 | port-gentil
# Processing Record 31 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 7 | port lincoln
# Processing Record 33 of Set 7 | meulaboh
# Processing Record 34 of Set 7 | buala
# Processing Record 35 of Set 7 | lufkin
# Processing Record 36 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 7 | tezu
# Processing Record 38 of Set 7 | zaozerne
# Processing Record 39 of Set 7 | lewiston
# Processing Record 40 of Set 7 | duns
# Processing Record 41 of Set 7 | areia branca
# Processing Record 42 of Set 7 | linxia
# Processing Record 43 of Set 7 | dunedin
# Processing Record 44 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 7 | hede
# Processing Record 46 of Set 7 | dire dawa
# Processing Record 47 of Set 7 | sibolga
# Processing Record 48 of Set 7 | tambun
# Processing Record 49 of Set 7 | tigil
# Processing Record 50 of Set 7 | darasun
# Processing Record 1 of Set 8 | galveston
# Processing Record 2 of Set 8 | abha
# Processing Record 3 of Set 8 | sindor
# Processing Record 4 of Set 8 | little current
# Processing Record 5 of Set 8 | shimoda
# Processing Record 6 of Set 8 | tasiilaq
# Processing Record 7 of Set 8 | gamba
# Processing Record 8 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 8 | san rafael
# Processing Record 10 of Set 8 | chumikan
# Processing Record 11 of Set 8 | bandarbeyla
# Processing Record 12 of Set 8 | champerico
# Processing Record 13 of Set 8 | saskylakh
# Processing Record 14 of Set 8 | tsaratanana
# Processing Record 15 of Set 8 | inirida
# Processing Record 16 of Set 8 | sawtell
# Processing Record 17 of Set 8 | humberto de campos
# Processing Record 18 of Set 8 | fortuna
# Processing Record 19 of Set 8 | lake city
# Processing Record 20 of Set 8 | corinto
# Processing Record 21 of Set 8 | bahia blanca
# Processing Record 22 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 8 | oswego
# Processing Record 24 of Set 8 | tateyama
# Processing Record 25 of Set 8 | evensk
# Processing Record 26 of Set 8 | kansanshi
# Processing Record 27 of Set 8 | xichang
# Processing Record 28 of Set 8 | vanino
# Processing Record 29 of Set 8 | pozo colorado
# Processing Record 30 of Set 8 | beyneu
# Processing Record 31 of Set 8 | mount isa
# Processing Record 32 of Set 8 | henties bay
# Processing Record 33 of Set 8 | turbat
# Processing Record 34 of Set 8 | vanderhoof
# Processing Record 35 of Set 8 | upata
# Processing Record 36 of Set 8 | dodola
# Processing Record 37 of Set 8 | kysyl-syr
# Processing Record 38 of Set 8 | provideniya
# Processing Record 39 of Set 8 | nizhnekamsk
# Processing Record 40 of Set 8 | avera
# Processing Record 41 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 8 | port hardy
# Processing Record 43 of Set 8 | torbat-e jam
# Processing Record 44 of Set 8 | ordu
# Processing Record 45 of Set 8 | hay river
# Processing Record 46 of Set 8 | pouembout
# Processing Record 47 of Set 8 | concarneau
# Processing Record 48 of Set 8 | big spring
# Processing Record 49 of Set 8 | ambilobe
# Processing Record 50 of Set 8 | la ronge
# Processing Record 1 of Set 9 | vardo
# Processing Record 2 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 9 | walvis bay
# Processing Record 4 of Set 9 | parauna
# Processing Record 5 of Set 9 | bratsk
# Processing Record 6 of Set 9 | gizo
# Processing Record 7 of Set 9 | pella
# Processing Record 8 of Set 9 | berlevag
# Processing Record 9 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 9 | kununurra
# Processing Record 11 of Set 9 | dossor
# Processing Record 12 of Set 9 | san cristobal
# Processing Record 13 of Set 9 | clyde river
# Processing Record 14 of Set 9 | sur
# Processing Record 15 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 9 | beloha
# Processing Record 17 of Set 9 | luderitz
# Processing Record 18 of Set 9 | montrose
# Processing Record 19 of Set 9 | ulladulla
# Processing Record 20 of Set 9 | salmas
# Processing Record 21 of Set 9 | gao
# Processing Record 22 of Set 9 | shaowu
# Processing Record 23 of Set 9 | hamilton
# Processing Record 24 of Set 9 | sao filipe
# Processing Record 25 of Set 9 | gelemso
# Processing Record 26 of Set 9 | narsaq
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | yandoon
# City not found. Skipping...
# Processing Record 29 of Set 9 | raudeberg
# Processing Record 30 of Set 9 | singleton
# Processing Record 31 of Set 9 | kosh-agach
# Processing Record 32 of Set 9 | basudebpur
# Processing Record 33 of Set 9 | kachug
# Processing Record 34 of Set 9 | nurlat
# Processing Record 35 of Set 9 | constitucion
# Processing Record 36 of Set 9 | coihaique
# Processing Record 37 of Set 9 | marienburg
# Processing Record 38 of Set 9 | moyale
# Processing Record 39 of Set 9 | milkovo
# Processing Record 40 of Set 9 | nanyang
# Processing Record 41 of Set 9 | indramayu
# Processing Record 42 of Set 9 | bima
# Processing Record 43 of Set 9 | sorland
# Processing Record 44 of Set 9 | granville
# Processing Record 45 of Set 9 | vila franca do campo
# Processing Record 46 of Set 9 | kaabong
# Processing Record 47 of Set 9 | te anau
# Processing Record 48 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 9 | lethem
# Processing Record 50 of Set 9 | leander
# Processing Record 1 of Set 10 | itarema
# Processing Record 2 of Set 10 | hambantota
# Processing Record 3 of Set 10 | wanning
# Processing Record 4 of Set 10 | norman wells
# Processing Record 5 of Set 10 | makakilo city
# Processing Record 6 of Set 10 | garmsar
# Processing Record 7 of Set 10 | ilanskiy
# Processing Record 8 of Set 10 | sambava
# Processing Record 9 of Set 10 | port-cartier
# Processing Record 10 of Set 10 | sumenep
# Processing Record 11 of Set 10 | san luis
# Processing Record 12 of Set 10 | faanui
# Processing Record 13 of Set 10 | bayan
# Processing Record 14 of Set 10 | saint anthony
# Processing Record 15 of Set 10 | saint-pierre
# Processing Record 16 of Set 10 | ormond beach
# Processing Record 17 of Set 10 | manicore
# Processing Record 18 of Set 10 | sangmelima
# Processing Record 19 of Set 10 | grand gaube
# Processing Record 20 of Set 10 | isangel
# Processing Record 21 of Set 10 | pudozh
# Processing Record 22 of Set 10 | coahuayana
# Processing Record 23 of Set 10 | borogontsy
# Processing Record 24 of Set 10 | kushima
# Processing Record 25 of Set 10 | xiongzhou
# Processing Record 26 of Set 10 | saquena
# Processing Record 27 of Set 10 | sioux lookout
# Processing Record 28 of Set 10 | hasaki
# Processing Record 29 of Set 10 | haicheng
# Processing Record 30 of Set 10 | pampa
# Processing Record 31 of Set 10 | miles city
# Processing Record 32 of Set 10 | faya
# Processing Record 33 of Set 10 | mango
# Processing Record 34 of Set 10 | mayya
# Processing Record 35 of Set 10 | pitimbu
# Processing Record 36 of Set 10 | brownwood
# Processing Record 37 of Set 10 | nyakabindi
# Processing Record 38 of Set 10 | plouzane
# Processing Record 39 of Set 10 | peterhead
# Processing Record 40 of Set 10 | newport
# Processing Record 41 of Set 10 | suba
# Processing Record 42 of Set 10 | ainazi
# Processing Record 43 of Set 10 | tongliao
# Processing Record 44 of Set 10 | ketchikan
# Processing Record 45 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 10 | reshetylivka
# Processing Record 47 of Set 10 | tiarei
# Processing Record 48 of Set 10 | moerai
# Processing Record 49 of Set 10 | bam
# Processing Record 50 of Set 10 | plainview
# Processing Record 1 of Set 11 | shingu
# Processing Record 2 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 3 of Set 11 | klyuchevskiy
# Processing Record 4 of Set 11 | payo
# Processing Record 5 of Set 11 | katherine
# Processing Record 6 of Set 11 | mabaruma
# Processing Record 7 of Set 11 | monterey
# Processing Record 8 of Set 11 | nizwa
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | olinda
# Processing Record 11 of Set 11 | pavlodar
# Processing Record 12 of Set 11 | bairiki
# Processing Record 13 of Set 11 | billings
# Processing Record 14 of Set 11 | giyani
# Processing Record 15 of Set 11 | tanout
# Processing Record 16 of Set 11 | breytovo
# Processing Record 17 of Set 11 | mocuba
# Processing Record 18 of Set 11 | naurskaya
# Processing Record 19 of Set 11 | zhangjiakou
# Processing Record 20 of Set 11 | the pas
# Processing Record 21 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 11 | abashiri
# Processing Record 23 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 11 | shache
# Processing Record 25 of Set 11 | komsomolskiy
# Processing Record 26 of Set 11 | saint-augustin
# Processing Record 27 of Set 11 | sisimiut
# Processing Record 28 of Set 11 | uyemskiy
# Processing Record 29 of Set 11 | syracuse
# Processing Record 30 of Set 11 | lorengau
# Processing Record 31 of Set 11 | aguimes
# Processing Record 32 of Set 11 | doha
# Processing Record 33 of Set 11 | pekalongan
# Processing Record 34 of Set 11 | iracoubo
# Processing Record 35 of Set 11 | awbari
# Processing Record 36 of Set 11 | tirano
# Processing Record 37 of Set 11 | russko-vysotskoye
# Processing Record 38 of Set 11 | mankono
# Processing Record 39 of Set 11 | dongning
# Processing Record 40 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 11 | karoi
# Processing Record 42 of Set 11 | jieshi
# Processing Record 43 of Set 11 | lakes entrance
# Processing Record 44 of Set 11 | genhe
# Processing Record 45 of Set 11 | christchurch
# Processing Record 46 of Set 11 | yoichi
# Processing Record 47 of Set 11 | naqadeh
# Processing Record 48 of Set 11 | chik ballapur
# Processing Record 49 of Set 11 | honningsvag
# Processing Record 50 of Set 11 | kupang
# Processing Record 1 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 12 | touros
# Processing Record 3 of Set 12 | puerto del rosario
# Processing Record 4 of Set 12 | hailey
# Processing Record 5 of Set 12 | adeje
# Processing Record 6 of Set 12 | algiers
# Processing Record 7 of Set 12 | marsaxlokk
# Processing Record 8 of Set 12 | codrington
# Processing Record 9 of Set 12 | katsuura
# Processing Record 10 of Set 12 | warmbad
# Processing Record 11 of Set 12 | qinggang
# Processing Record 12 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 12 | stawell
# Processing Record 14 of Set 12 | wilmington
# Processing Record 15 of Set 12 | tadine
# Processing Record 16 of Set 12 | jiuquan
# Processing Record 17 of Set 12 | cardoso
# Processing Record 18 of Set 12 | cockburn town
# Processing Record 19 of Set 12 | lloydminster
# Processing Record 20 of Set 12 | san quintin
# Processing Record 21 of Set 12 | tocopilla
# Processing Record 22 of Set 12 | koslan
# Processing Record 23 of Set 12 | srednekolymsk
# Processing Record 24 of Set 12 | vestmanna
# Processing Record 25 of Set 12 | ileza
# Processing Record 26 of Set 12 | northam
# Processing Record 27 of Set 12 | lengshuijiang
# Processing Record 28 of Set 12 | stekolnyy
# City not found. Skipping...
# Processing Record 29 of Set 12 | pochutla
# Processing Record 30 of Set 12 | qingdao
# Processing Record 31 of Set 12 | thunder bay
# Processing Record 32 of Set 12 | beringovskiy
# Processing Record 33 of Set 12 | birao
# Processing Record 34 of Set 12 | behshahr
# Processing Record 35 of Set 12 | paducah
# Processing Record 36 of Set 12 | ziarat
# Processing Record 37 of Set 12 | brae
# Processing Record 38 of Set 12 | gongzhuling
# Processing Record 39 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 12 | westport
# Processing Record 41 of Set 12 | bathsheba
# Processing Record 42 of Set 12 | ocos
# Processing Record 43 of Set 12 | ingham
# Processing Record 44 of Set 12 | koumac
# Processing Record 45 of Set 12 | ternate
# Processing Record 46 of Set 12 | buenos aires
# Processing Record 47 of Set 12 | opuwo
# Processing Record 48 of Set 12 | grindavik
# Processing Record 49 of Set 12 | mehamn
# Processing Record 50 of Set 12 | karema
# Processing Record 1 of Set 13 | russell
# Processing Record 2 of Set 13 | cheney
# Processing Record 3 of Set 13 | grand-lahou
# Processing Record 4 of Set 13 | neiafu
# Processing Record 5 of Set 13 | whitianga
# Processing Record 6 of Set 13 | farrukhnagar
# Processing Record 7 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 13 | ushtobe
# Processing Record 9 of Set 13 | am timan
# Processing Record 10 of Set 13 | belyy yar
# Processing Record 11 of Set 13 | san juan
# Processing Record 12 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 13 | lucea
# Processing Record 14 of Set 13 | chita
# Processing Record 15 of Set 13 | barcelos
# Processing Record 16 of Set 13 | olafsvik
# Processing Record 17 of Set 13 | jining
# Processing Record 18 of Set 13 | kedougou
# Processing Record 19 of Set 13 | sandusky
# Processing Record 20 of Set 13 | saldanha
# Processing Record 21 of Set 13 | waingapu
# Processing Record 22 of Set 13 | whyalla
# Processing Record 23 of Set 13 | kalininsk
# Processing Record 24 of Set 13 | malanje
# Processing Record 25 of Set 13 | pandan
# Processing Record 26 of Set 13 | biak
# Processing Record 27 of Set 13 | cap malheureux
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame with columns in order
city_data_df = pd.DataFrame(city_data, 
                            columns=["City", "Country", "Date", "Lat", "Lng",
                                     "Max Temp", "Humidity", "Cloudiness", "Wind Speed"])
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0    Punta Arenas      CL  2022-06-28 17:59:41 -53.1500  -70.9167     41.11
# 1        Matinhos      BR  2022-06-28 17:59:41 -25.8175  -48.5428     75.90
# 2           Bluff      NZ  2022-06-28 17:59:42 -46.6000  168.3333     40.80
# 3      Oranjemund      NA  2022-06-28 17:59:42 -28.5500   16.4333     72.45
# 4      Nanortalik      GL  2022-06-28 17:59:42  60.1432  -45.2371     47.07
# 5         Teguise      ES  2022-06-28 17:59:42  29.0605  -13.5640     71.82
# 6          Rawson      AR  2022-06-28 17:59:43 -43.3002  -65.1023     57.02
# 7       Carnarvon      AU  2022-06-28 17:55:42 -24.8667  113.6333     65.28
# 8       Jamestown      US  2022-06-28 17:59:24  42.0970  -79.2353     70.95
# 9  Cabo San Lucas      MX  2022-06-28 17:59:43  22.8909 -109.9124     92.61
#
#    Humidity  Cloudiness  Wind Speed
# 0        75          75       12.66
# 1        70          30        6.44
# 2        77         100       19.30
# 3        32           0       10.98
# 4        66         100       14.50
# 5        57          40       21.85
# 6        48         100       20.89
# 7        43           0       17.76
# 8        51           0        3.00
# 9        66         100        5.86

# %%
# Create the output file (CSV).
# specify the path - in this case it will save in same place as WeatherPy.ipynb
output_data_file = "cities.csv" 
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
