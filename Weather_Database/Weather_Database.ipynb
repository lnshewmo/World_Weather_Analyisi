# %% [markdown]
# # Weather_Database.ipynb

# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key

# %%
# create a set of random lat long combinations
lats = np.random.uniform(low=-90,high=90, size =2000)
longs = np.random.uniform(-180,180, 2000)
lat_longs= zip(lats, longs)
lat_longs

# %%
coordinates = list(lat_longs)

# %%
# for coordinate in coordinates:
   # print(coordinate[0], coordinate[1])

# %%
# create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, add to the cities list
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient quantity
len(cities)
# Out:
# 733

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
# initialized the counters at 1 bc we want to start both at 1
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in our list
# create the for loop with the enumerate() method and reference the index and the city in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    # tell program to pause 60 sec bc the API oly allows 60 calls per min for free
    # prevents time out errors
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count 
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_dx = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_current_dx,
                          "Country": city_country})
                          #"Date": city_date
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        # pass handles all errors and allows to continue
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | san cristobal
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | nabire
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | verkhoturye
# Processing Record 18 of Set 1 | chuy
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 1 | klaksvik
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | khatanga
# Processing Record 27 of Set 1 | batagay-alyta
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 1 | lompoc
# Processing Record 31 of Set 1 | klichka
# Processing Record 32 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | ust-kuyga
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | quatre cocos
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | beyneu
# Processing Record 41 of Set 1 | vitim
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | camalu
# Processing Record 44 of Set 1 | coihaique
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | grand gaube
# Processing Record 47 of Set 1 | loa janan
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | tura
# Processing Record 50 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 2 | lisieux
# Processing Record 2 of Set 2 | nome
# Processing Record 3 of Set 2 | pangody
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | aklavik
# Processing Record 6 of Set 2 | mega
# Processing Record 7 of Set 2 | port dover
# Processing Record 8 of Set 2 | geraldton
# Processing Record 9 of Set 2 | walvis bay
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | sitka
# Processing Record 12 of Set 2 | sao filipe
# Processing Record 13 of Set 2 | kungurtug
# Processing Record 14 of Set 2 | bathsheba
# Processing Record 15 of Set 2 | pizarro
# Processing Record 16 of Set 2 | haderslev
# Processing Record 17 of Set 2 | clyde river
# Processing Record 18 of Set 2 | nizwa
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | yeppoon
# Processing Record 22 of Set 2 | kruisfontein
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | ha tinh
# Processing Record 25 of Set 2 | havre-saint-pierre
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | impfondo
# Processing Record 31 of Set 2 | dunedin
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | bonavista
# Processing Record 35 of Set 2 | barentu
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | mabaruma
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | labuhan
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | nizhniy baskunchak
# Processing Record 43 of Set 2 | ambanja
# Processing Record 44 of Set 2 | jakar
# Processing Record 45 of Set 2 | nishihara
# Processing Record 46 of Set 2 | dakar
# Processing Record 47 of Set 2 | muroto
# Processing Record 48 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 2 | salaga
# Processing Record 50 of Set 2 | whitianga
# Processing Record 1 of Set 3 | fairbanks
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | gwanda
# Processing Record 4 of Set 3 | portland
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | narsaq
# Processing Record 7 of Set 3 | haverhill
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | angoram
# Processing Record 11 of Set 3 | rio tercero
# Processing Record 12 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 3 | weinan
# Processing Record 14 of Set 3 | tiznit
# Processing Record 15 of Set 3 | katha
# City not found. Skipping...
# Processing Record 16 of Set 3 | vuktyl
# Processing Record 17 of Set 3 | lavrentiya
# Processing Record 18 of Set 3 | mataura
# Processing Record 19 of Set 3 | abeokuta
# Processing Record 20 of Set 3 | ahipara
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | arlit
# Processing Record 23 of Set 3 | aktas
# Processing Record 24 of Set 3 | college
# Processing Record 25 of Set 3 | noshiro
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | port alberni
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | arraial do cabo
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | north platte
# Processing Record 32 of Set 3 | vila franca do campo
# Processing Record 33 of Set 3 | souillac
# Processing Record 34 of Set 3 | provideniya
# Processing Record 35 of Set 3 | acapulco
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | pevek
# Processing Record 38 of Set 3 | san francisco
# Processing Record 39 of Set 3 | aljezur
# Processing Record 40 of Set 3 | liverpool
# Processing Record 41 of Set 3 | nouadhibou
# Processing Record 42 of Set 3 | luocheng
# Processing Record 43 of Set 3 | qasigiannguit
# Processing Record 44 of Set 3 | byron bay
# Processing Record 45 of Set 3 | kristiansund
# Processing Record 46 of Set 3 | panchagarh
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | kamenka
# Processing Record 50 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 4 | kosovo polje
# Processing Record 2 of Set 4 | ridgecrest
# Processing Record 3 of Set 4 | kavieng
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | taoudenni
# Processing Record 6 of Set 4 | cazones
# Processing Record 7 of Set 4 | dondo
# Processing Record 8 of Set 4 | atkinson
# Processing Record 9 of Set 4 | bud
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | tuatapere
# Processing Record 12 of Set 4 | cidreira
# Processing Record 13 of Set 4 | carnarvon
# Processing Record 14 of Set 4 | talnakh
# Processing Record 15 of Set 4 | guelengdeng
# City not found. Skipping...
# Processing Record 16 of Set 4 | novita
# Processing Record 17 of Set 4 | bambanglipuro
# Processing Record 18 of Set 4 | kolobrzeg
# Processing Record 19 of Set 4 | poum
# Processing Record 20 of Set 4 | victoria falls
# Processing Record 21 of Set 4 | berlevag
# Processing Record 22 of Set 4 | alexandria
# Processing Record 23 of Set 4 | saldanha
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | urdoma
# Processing Record 26 of Set 4 | benin
# Processing Record 27 of Set 4 | los llanos de aridane
# Processing Record 28 of Set 4 | bonthe
# Processing Record 29 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 30 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 4 | cockburn town
# Processing Record 32 of Set 4 | laramie
# Processing Record 33 of Set 4 | karpathos
# Processing Record 34 of Set 4 | san vicente de canete
# Processing Record 35 of Set 4 | flin flon
# Processing Record 36 of Set 4 | kpandu
# Processing Record 37 of Set 4 | kushmurun
# Processing Record 38 of Set 4 | sandwick
# Processing Record 39 of Set 4 | gazojak
# Processing Record 40 of Set 4 | vostok
# Processing Record 41 of Set 4 | bello
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | bumba
# Processing Record 44 of Set 4 | bambous virieux
# Processing Record 45 of Set 4 | puerto ayora
# Processing Record 46 of Set 4 | buala
# Processing Record 47 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 4 | airai
# Processing Record 49 of Set 4 | kasra
# City not found. Skipping...
# Processing Record 50 of Set 4 | adrar
# Processing Record 1 of Set 5 | emerald
# Processing Record 2 of Set 5 | tazovskiy
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | salalah
# Processing Record 5 of Set 5 | karratha
# Processing Record 6 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 5 | tsumeb
# Processing Record 8 of Set 5 | sechura
# Processing Record 9 of Set 5 | teruel
# Processing Record 10 of Set 5 | merauke
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | deputatskiy
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | lalomanu
# City not found. Skipping...
# Processing Record 15 of Set 5 | vardo
# Processing Record 16 of Set 5 | kampot
# Processing Record 17 of Set 5 | papayal
# Processing Record 18 of Set 5 | severo-kurilsk
# Processing Record 19 of Set 5 | faya
# Processing Record 20 of Set 5 | santa maria
# Processing Record 21 of Set 5 | vanersborg
# Processing Record 22 of Set 5 | nabinagar
# Processing Record 23 of Set 5 | launceston
# Processing Record 24 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 5 | fos-sur-mer
# Processing Record 26 of Set 5 | port hedland
# Processing Record 27 of Set 5 | may pen
# Processing Record 28 of Set 5 | tessalit
# Processing Record 29 of Set 5 | san carlos de bariloche
# Processing Record 30 of Set 5 | kahului
# Processing Record 31 of Set 5 | sioux lookout
# Processing Record 32 of Set 5 | samarai
# Processing Record 33 of Set 5 | buraydah
# Processing Record 34 of Set 5 | terney
# Processing Record 35 of Set 5 | richards bay
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | vao
# Processing Record 38 of Set 5 | ulladulla
# Processing Record 39 of Set 5 | burica
# City not found. Skipping...
# Processing Record 40 of Set 5 | dalby
# Processing Record 41 of Set 5 | kuytun
# Processing Record 42 of Set 5 | constitucion
# Processing Record 43 of Set 5 | shakawe
# Processing Record 44 of Set 5 | staraya poltavka
# Processing Record 45 of Set 5 | mocuba
# Processing Record 46 of Set 5 | faanui
# Processing Record 47 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 48 of Set 5 | mayo
# Processing Record 49 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 5 | kaeo
# Processing Record 1 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 6 | bandarbeyla
# Processing Record 3 of Set 6 | bocana de paiwas
# Processing Record 4 of Set 6 | channel-port aux basques
# Processing Record 5 of Set 6 | terrace
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | ponta do sol
# Processing Record 8 of Set 6 | manta
# Processing Record 9 of Set 6 | lagoa
# Processing Record 10 of Set 6 | det udom
# Processing Record 11 of Set 6 | amargosa
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | makato
# Processing Record 14 of Set 6 | iztapa
# Processing Record 15 of Set 6 | broken hill
# Processing Record 16 of Set 6 | sterling
# Processing Record 17 of Set 6 | hambantota
# Processing Record 18 of Set 6 | taunggyi
# Processing Record 19 of Set 6 | tilichiki
# Processing Record 20 of Set 6 | nantucket
# Processing Record 21 of Set 6 | makakilo city
# Processing Record 22 of Set 6 | presidencia roque saenz pena
# Processing Record 23 of Set 6 | kavaratti
# Processing Record 24 of Set 6 | wasilla
# Processing Record 25 of Set 6 | bossangoa
# Processing Record 26 of Set 6 | barillas
# Processing Record 27 of Set 6 | el coyote
# Processing Record 28 of Set 6 | hami
# Processing Record 29 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 6 | chippewa falls
# Processing Record 31 of Set 6 | vytegra
# Processing Record 32 of Set 6 | valdivia
# Processing Record 33 of Set 6 | pangnirtung
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | meadow lake
# Processing Record 36 of Set 6 | mokolo
# Processing Record 37 of Set 6 | tupik
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 40 of Set 6 | mount gambier
# Processing Record 41 of Set 6 | fenton
# Processing Record 42 of Set 6 | maracacume
# Processing Record 43 of Set 6 | lodwar
# Processing Record 44 of Set 6 | campobello di mazara
# Processing Record 45 of Set 6 | changde
# Processing Record 46 of Set 6 | del rio
# Processing Record 47 of Set 6 | balkanabat
# Processing Record 48 of Set 6 | puerto del rosario
# Processing Record 49 of Set 6 | aksu
# Processing Record 50 of Set 6 | east london
# Processing Record 1 of Set 7 | paamiut
# Processing Record 2 of Set 7 | horuphav
# Processing Record 3 of Set 7 | barguzin
# Processing Record 4 of Set 7 | sylvania
# Processing Record 5 of Set 7 | haines junction
# Processing Record 6 of Set 7 | sambava
# Processing Record 7 of Set 7 | newport
# Processing Record 8 of Set 7 | namatanai
# Processing Record 9 of Set 7 | alto baudo
# City not found. Skipping...
# Processing Record 10 of Set 7 | fairfield
# Processing Record 11 of Set 7 | yakeshi
# Processing Record 12 of Set 7 | ruwi
# Processing Record 13 of Set 7 | rawson
# Processing Record 14 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 15 of Set 7 | port elizabeth
# Processing Record 16 of Set 7 | narasannapeta
# Processing Record 17 of Set 7 | praia da vitoria
# Processing Record 18 of Set 7 | sinnamary
# Processing Record 19 of Set 7 | cowra
# Processing Record 20 of Set 7 | kirakira
# Processing Record 21 of Set 7 | saint-louis
# Processing Record 22 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 7 | la ronge
# Processing Record 24 of Set 7 | fortuna
# Processing Record 25 of Set 7 | guican
# Processing Record 26 of Set 7 | ilhabela
# Processing Record 27 of Set 7 | adre
# Processing Record 28 of Set 7 | nolinsk
# Processing Record 29 of Set 7 | iquique
# Processing Record 30 of Set 7 | san jose
# Processing Record 31 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 7 | oranjemund
# Processing Record 33 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 7 | mansa
# Processing Record 36 of Set 7 | dapaong
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | kildare
# Processing Record 39 of Set 7 | bilibino
# Processing Record 40 of Set 7 | amapala
# Processing Record 41 of Set 7 | ulaangom
# Processing Record 42 of Set 7 | balad
# Processing Record 43 of Set 7 | ancud
# Processing Record 44 of Set 7 | khasan
# Processing Record 45 of Set 7 | moanda
# Processing Record 46 of Set 7 | amahai
# Processing Record 47 of Set 7 | merrill
# Processing Record 48 of Set 7 | akyab
# Processing Record 49 of Set 7 | torbay
# Processing Record 50 of Set 7 | gimli
# Processing Record 1 of Set 8 | esperance
# Processing Record 2 of Set 8 | norman wells
# Processing Record 3 of Set 8 | carinhanha
# Processing Record 4 of Set 8 | sussex
# Processing Record 5 of Set 8 | bundaberg
# Processing Record 6 of Set 8 | caravelas
# Processing Record 7 of Set 8 | hudson bay
# Processing Record 8 of Set 8 | kirkwall
# Processing Record 9 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 10 of Set 8 | aldan
# Processing Record 11 of Set 8 | porto velho
# Processing Record 12 of Set 8 | florianopolis
# Processing Record 13 of Set 8 | luderitz
# Processing Record 14 of Set 8 | almaznyy
# Processing Record 15 of Set 8 | victoria
# Processing Record 16 of Set 8 | gizo
# Processing Record 17 of Set 8 | mao
# Processing Record 18 of Set 8 | flinders
# Processing Record 19 of Set 8 | shimoda
# Processing Record 20 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 21 of Set 8 | teguldet
# Processing Record 22 of Set 8 | aqtobe
# Processing Record 23 of Set 8 | terni
# Processing Record 24 of Set 8 | midland
# Processing Record 25 of Set 8 | gisborne
# Processing Record 26 of Set 8 | mlalo
# Processing Record 27 of Set 8 | maniitsoq
# Processing Record 28 of Set 8 | krasnogvardeyskiy
# Processing Record 29 of Set 8 | tuy hoa
# Processing Record 30 of Set 8 | chapais
# Processing Record 31 of Set 8 | aykhal
# Processing Record 32 of Set 8 | padang
# Processing Record 33 of Set 8 | shizunai
# Processing Record 34 of Set 8 | kaya
# Processing Record 35 of Set 8 | gunjur
# Processing Record 36 of Set 8 | palmas bellas
# Processing Record 37 of Set 8 | ekhabi
# Processing Record 38 of Set 8 | asfi
# Processing Record 39 of Set 8 | maragogi
# Processing Record 40 of Set 8 | kargapolye
# City not found. Skipping...
# Processing Record 41 of Set 8 | codrington
# Processing Record 42 of Set 8 | sakakah
# Processing Record 43 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 8 | manuk mangkaw
# Processing Record 45 of Set 8 | sawankhalok
# Processing Record 46 of Set 8 | bengkalis
# City not found. Skipping...
# Processing Record 47 of Set 8 | namibe
# Processing Record 48 of Set 8 | onega
# Processing Record 49 of Set 8 | qandala
# Processing Record 50 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 1 of Set 9 | shingu
# Processing Record 2 of Set 9 | benguela
# Processing Record 3 of Set 9 | jurm
# Processing Record 4 of Set 9 | young
# Processing Record 5 of Set 9 | katsuura
# Processing Record 6 of Set 9 | harper
# Processing Record 7 of Set 9 | victoria point
# Processing Record 8 of Set 9 | san policarpo
# Processing Record 9 of Set 9 | hamilton
# Processing Record 10 of Set 9 | takoradi
# Processing Record 11 of Set 9 | tabou
# Processing Record 12 of Set 9 | kobojango
# City not found. Skipping...
# Processing Record 13 of Set 9 | huarmey
# Processing Record 14 of Set 9 | port-gentil
# Processing Record 15 of Set 9 | marsa matruh
# Processing Record 16 of Set 9 | banda aceh
# Processing Record 17 of Set 9 | eldorado
# Processing Record 18 of Set 9 | kushima
# Processing Record 19 of Set 9 | isiro
# Processing Record 20 of Set 9 | izmit
# Processing Record 21 of Set 9 | isangel
# Processing Record 22 of Set 9 | grindavik
# Processing Record 23 of Set 9 | namwala
# Processing Record 24 of Set 9 | riyadh
# Processing Record 25 of Set 9 | muscat
# Processing Record 26 of Set 9 | thetford mines
# Processing Record 27 of Set 9 | olinda
# Processing Record 28 of Set 9 | nara
# Processing Record 29 of Set 9 | pisco
# Processing Record 30 of Set 9 | maningrida
# Processing Record 31 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 9 | san quintin
# Processing Record 33 of Set 9 | port barton
# Processing Record 34 of Set 9 | waddan
# Processing Record 35 of Set 9 | okulovka
# Processing Record 36 of Set 9 | yulara
# Processing Record 37 of Set 9 | dukat
# Processing Record 38 of Set 9 | esil
# Processing Record 39 of Set 9 | zyryanka
# Processing Record 40 of Set 9 | lasa
# Processing Record 41 of Set 9 | solok
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | te anau
# Processing Record 44 of Set 9 | santa rosa
# Processing Record 45 of Set 9 | marystown
# Processing Record 46 of Set 9 | hualmay
# Processing Record 47 of Set 9 | barra patuca
# Processing Record 48 of Set 9 | mandaguacu
# Processing Record 49 of Set 9 | shiyan
# Processing Record 50 of Set 9 | batagay
# Processing Record 1 of Set 10 | tefe
# Processing Record 2 of Set 10 | dzilam gonzalez
# Processing Record 3 of Set 10 | chaohu
# Processing Record 4 of Set 10 | port maria
# Processing Record 5 of Set 10 | yantal
# Processing Record 6 of Set 10 | andros town
# Processing Record 7 of Set 10 | leningradskiy
# Processing Record 8 of Set 10 | kloulklubed
# Processing Record 9 of Set 10 | barranca
# Processing Record 10 of Set 10 | pryazha
# Processing Record 11 of Set 10 | port macquarie
# Processing Record 12 of Set 10 | tulun
# Processing Record 13 of Set 10 | nemuro
# Processing Record 14 of Set 10 | marzuq
# Processing Record 15 of Set 10 | concepcion del uruguay
# Processing Record 16 of Set 10 | russell
# Processing Record 17 of Set 10 | abu kamal
# Processing Record 18 of Set 10 | vila velha
# Processing Record 19 of Set 10 | ibra
# Processing Record 20 of Set 10 | mezen
# Processing Record 21 of Set 10 | saint-augustin
# Processing Record 22 of Set 10 | rezekne
# Processing Record 23 of Set 10 | galle
# Processing Record 24 of Set 10 | sidi ali
# Processing Record 25 of Set 10 | matara
# Processing Record 26 of Set 10 | waingapu
# Processing Record 27 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 10 | causapscal
# Processing Record 29 of Set 10 | shache
# Processing Record 30 of Set 10 | yatou
# Processing Record 31 of Set 10 | sorrento
# Processing Record 32 of Set 10 | jalu
# Processing Record 33 of Set 10 | agidel
# Processing Record 34 of Set 10 | lorengau
# Processing Record 35 of Set 10 | maple creek
# Processing Record 36 of Set 10 | moville
# Processing Record 37 of Set 10 | ji-parana
# City not found. Skipping...
# Processing Record 38 of Set 10 | longyearbyen
# Processing Record 39 of Set 10 | qui nhon
# Processing Record 40 of Set 10 | jelah
# Processing Record 41 of Set 10 | luneburg
# Processing Record 42 of Set 10 | monrovia
# Processing Record 43 of Set 10 | inirida
# Processing Record 44 of Set 10 | lufilufi
# Processing Record 45 of Set 10 | kempsey
# Processing Record 46 of Set 10 | sorgun
# Processing Record 47 of Set 10 | stornoway
# Processing Record 48 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 10 | aromashevo
# Processing Record 50 of Set 10 | tateyama
# Processing Record 1 of Set 11 | caracoli
# Processing Record 2 of Set 11 | stolin
# Processing Record 3 of Set 11 | chingirlau
# Processing Record 4 of Set 11 | bolshaya dzhalga
# Processing Record 5 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 11 | eureka
# Processing Record 7 of Set 11 | feijo
# Processing Record 8 of Set 11 | sri aman
# Processing Record 9 of Set 11 | sao borja
# Processing Record 10 of Set 11 | ballina
# Processing Record 11 of Set 11 | auki
# Processing Record 12 of Set 11 | mehamn
# Processing Record 13 of Set 11 | hervey bay
# Processing Record 14 of Set 11 | alugan
# Processing Record 15 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 11 | caborca
# Processing Record 17 of Set 11 | taywarah
# Processing Record 18 of Set 11 | ostrovnoy
# Processing Record 19 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 11 | yenagoa
# Processing Record 21 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 11 | parana
# Processing Record 23 of Set 11 | san juan
# Processing Record 24 of Set 11 | greenville
# Processing Record 25 of Set 11 | comodoro rivadavia
# Processing Record 26 of Set 11 | ontario
# Processing Record 27 of Set 11 | severnyy
# Processing Record 28 of Set 11 | talara
# Processing Record 29 of Set 11 | mackenzie
# Processing Record 30 of Set 11 | saint-francois
# Processing Record 31 of Set 11 | placido de castro
# Processing Record 32 of Set 11 | husavik
# Processing Record 33 of Set 11 | state college
# Processing Record 34 of Set 11 | buin
# Processing Record 35 of Set 11 | burnie
# Processing Record 36 of Set 11 | makinsk
# Processing Record 37 of Set 11 | yueyang
# Processing Record 38 of Set 11 | trairi
# Processing Record 39 of Set 11 | vanderhoof
# Processing Record 40 of Set 11 | cuenca
# Processing Record 41 of Set 11 | pinar del rio
# Processing Record 42 of Set 11 | santa fe
# Processing Record 43 of Set 11 | thaton
# Processing Record 44 of Set 11 | basco
# Processing Record 45 of Set 11 | goderich
# Processing Record 46 of Set 11 | kirksville
# Processing Record 47 of Set 11 | asosa
# Processing Record 48 of Set 11 | ogaminana
# Processing Record 49 of Set 11 | srandakan
# Processing Record 50 of Set 11 | voh
# Processing Record 1 of Set 12 | gorele
# Processing Record 2 of Set 12 | wuda
# Processing Record 3 of Set 12 | marawi
# Processing Record 4 of Set 12 | brigantine
# Processing Record 5 of Set 12 | cairns
# Processing Record 6 of Set 12 | el alto
# Processing Record 7 of Set 12 | dharchula
# Processing Record 8 of Set 12 | amarante do maranhao
# Processing Record 9 of Set 12 | lawton
# Processing Record 10 of Set 12 | sao joao da barra
# Processing Record 11 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 12 of Set 12 | sunland park
# Processing Record 13 of Set 12 | champerico
# Processing Record 14 of Set 12 | mayumba
# Processing Record 15 of Set 12 | yumen
# Processing Record 16 of Set 12 | sao miguel do araguaia
# Processing Record 17 of Set 12 | nanortalik
# Processing Record 18 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 19 of Set 12 | neryungri
# Processing Record 20 of Set 12 | carbonia
# Processing Record 21 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 12 | diego de almagro
# Processing Record 23 of Set 12 | shediac
# Processing Record 24 of Set 12 | san juan de uraba
# Processing Record 25 of Set 12 | atar
# Processing Record 26 of Set 12 | east moline
# Processing Record 27 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 12 | chandler
# Processing Record 29 of Set 12 | tougue
# Processing Record 30 of Set 12 | providencia
# Processing Record 31 of Set 12 | whitehorse
# Processing Record 32 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 12 | pacific grove
# Processing Record 34 of Set 12 | strezhevoy
# Processing Record 35 of Set 12 | sumkino
# Processing Record 36 of Set 12 | butembo
# Processing Record 37 of Set 12 | ahvaz
# Processing Record 38 of Set 12 | victor harbor
# Processing Record 39 of Set 12 | waikuku
# Processing Record 40 of Set 12 | boende
# Processing Record 41 of Set 12 | lovozero
# Processing Record 42 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 12 | kambove
# Processing Record 44 of Set 12 | atambua
# Processing Record 45 of Set 12 | katangli
# Processing Record 46 of Set 12 | leh
# Processing Record 47 of Set 12 | aksarka
# Processing Record 48 of Set 12 | ocos
# Processing Record 49 of Set 12 | north las vegas
# Processing Record 50 of Set 12 | juneau
# Processing Record 1 of Set 13 | selty
# Processing Record 2 of Set 13 | mahajanga
# Processing Record 3 of Set 13 | talpa
# Processing Record 4 of Set 13 | gujrat
# Processing Record 5 of Set 13 | yabassi
# Processing Record 6 of Set 13 | mudgee
# Processing Record 7 of Set 13 | wadsworth
# Processing Record 8 of Set 13 | igarka
# Processing Record 9 of Set 13 | sanmenxia
# Processing Record 10 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 11 of Set 13 | mahibadhoo
# Processing Record 12 of Set 13 | kushiro
# Processing Record 13 of Set 13 | khani
# Processing Record 14 of Set 13 | kikwit
# Processing Record 15 of Set 13 | kawalu
# Processing Record 16 of Set 13 | morondava
# Processing Record 17 of Set 13 | zhuhai
# Processing Record 18 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 19 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 13 | mersing
# Processing Record 21 of Set 13 | la asuncion
# Processing Record 22 of Set 13 | corralillo
# Processing Record 23 of Set 13 | karabulak
# Processing Record 24 of Set 13 | altay
# Processing Record 25 of Set 13 | muyezerskiy
# Processing Record 26 of Set 13 | raudeberg
# Processing Record 27 of Set 13 | abu dhabi
# Processing Record 28 of Set 13 | port-cartier
# Processing Record 29 of Set 13 | lazaro cardenas
# Processing Record 30 of Set 13 | north bend
# Processing Record 31 of Set 13 | zinder
# Processing Record 32 of Set 13 | lazurne
# Processing Record 33 of Set 13 | chingola
# Processing Record 34 of Set 13 | anadyr
# Processing Record 35 of Set 13 | cayenne
# Processing Record 36 of Set 13 | westport
# Processing Record 37 of Set 13 | yar-sale
# Processing Record 38 of Set 13 | cabedelo
# Processing Record 39 of Set 13 | georgiyevka
# Processing Record 40 of Set 13 | killybegs
# Processing Record 41 of Set 13 | pokrovsk
# Processing Record 42 of Set 13 | mount isa
# Processing Record 43 of Set 13 | belaya gora
# Processing Record 44 of Set 13 | adelaide
# Processing Record 45 of Set 13 | akdepe
# Processing Record 46 of Set 13 | pierre
# Processing Record 47 of Set 13 | touros
# Processing Record 48 of Set 13 | aswan
# Processing Record 49 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 13 | kalmunai
# Processing Record 1 of Set 14 | clermont
# Processing Record 2 of Set 14 | kieta
# Processing Record 3 of Set 14 | gemena
# Processing Record 4 of Set 14 | svetlogorsk
# Processing Record 5 of Set 14 | lima
# Processing Record 6 of Set 14 | esmeraldas
# Processing Record 7 of Set 14 | bakchar
# Processing Record 8 of Set 14 | asau
# Processing Record 9 of Set 14 | sompeta
# Processing Record 10 of Set 14 | lulea
# Processing Record 11 of Set 14 | kudahuvadhoo
# Processing Record 12 of Set 14 | masuda
# Processing Record 13 of Set 14 | rio claro
# Processing Record 14 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 14 | santa lucia
# Processing Record 16 of Set 14 | praia
# Processing Record 17 of Set 14 | belene
# Processing Record 18 of Set 14 | vestmannaeyjar
# Processing Record 19 of Set 14 | bitung
# Processing Record 20 of Set 14 | half moon bay
# Processing Record 21 of Set 14 | condega
# Processing Record 22 of Set 14 | kholtoson
# Processing Record 23 of Set 14 | toora-khem
# Processing Record 24 of Set 14 | olafsvik
# Processing Record 25 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 14 | ahuimanu
# Processing Record 27 of Set 14 | poya
# Processing Record 28 of Set 14 | west wendover
# Processing Record 29 of Set 14 | saint anthony
# Processing Record 30 of Set 14 | jining
# Processing Record 31 of Set 14 | costa rica
# Processing Record 32 of Set 14 | mareeba
# Processing Record 33 of Set 14 | cap malheureux
# Processing Record 34 of Set 14 | muana
# Processing Record 35 of Set 14 | charlestown
# Processing Record 36 of Set 14 | dawson creek
# Processing Record 37 of Set 14 | jinchang
# Processing Record 38 of Set 14 | gondanglegi
# Processing Record 39 of Set 14 | juba
# Processing Record 40 of Set 14 | ko samui
# Processing Record 41 of Set 14 | havelock
# Processing Record 42 of Set 14 | hofn
# Processing Record 43 of Set 14 | columbus
# Processing Record 44 of Set 14 | carupano
# Processing Record 45 of Set 14 | tabatinga
# Processing Record 46 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 14 | roma
# Processing Record 48 of Set 14 | kuopio
# Processing Record 49 of Set 14 | high level
# Processing Record 50 of Set 14 | luanda
# Processing Record 1 of Set 15 | benjamin hill
# Processing Record 2 of Set 15 | jacmel
# Processing Record 3 of Set 15 | gravdal
# Processing Record 4 of Set 15 | vaitape
# Processing Record 5 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 15 | rajpipla
# Processing Record 7 of Set 15 | carutapera
# Processing Record 8 of Set 15 | sabattus
# Processing Record 9 of Set 15 | saint-pierre
# Processing Record 10 of Set 15 | aldergrove
# Processing Record 11 of Set 15 | churapcha
# Processing Record 12 of Set 15 | primorsk
# Processing Record 13 of Set 15 | kabalo
# Processing Record 14 of Set 15 | candolim
# Processing Record 15 of Set 15 | piste
# Processing Record 16 of Set 15 | sao felix do xingu
# Processing Record 17 of Set 15 | xining
# Processing Record 18 of Set 15 | imeni poliny osipenko
# Processing Record 19 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 15 | tautira
# Processing Record 21 of Set 15 | grand-santi
# Processing Record 22 of Set 15 | pombia
# Processing Record 23 of Set 15 | isesaki
# Processing Record 24 of Set 15 | zemio
# Processing Record 25 of Set 15 | puerto carreno
# Processing Record 26 of Set 15 | prince rupert
# Processing Record 27 of Set 15 | boddam
# Processing Record 28 of Set 15 | yerbogachen
# Processing Record 29 of Set 15 | raga
# Processing Record 30 of Set 15 | skjervoy
# Processing Record 31 of Set 15 | tomohon
# Processing Record 32 of Set 15 | novikovo
# Processing Record 33 of Set 15 | concepcion del oro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data, columns=["City","Country","Lat","Lng",
                                                "Max Temp","Humidity","Cloudiness",
                                                "Wind Speed","Current Description"])
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Georgetown      MY   5.4112  100.3354     84.13        78          20
# 1      Upernavik      GL  72.7868  -56.1549     37.56        84         100
# 2    Port Alfred      ZA -33.5906   26.8910     67.91        38           0
# 3   Punta Arenas      CL -53.1500  -70.9167     37.51        65           0
# 4  San Cristobal      VE   7.7669  -72.2250     82.58        56          50
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1       11.14     overcast clouds
# 2       12.57           clear sky
# 3        5.75           clear sky
# 4        6.40    scattered clouds

# %%
output_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_file)

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 668 non-null    object
#  1   Country              668 non-null    object
#  2   Lat                  668 non-null    float64
#  3   Lng                  668 non-null    float64
#  4   Max Temp             668 non-null    float64
#  5   Humidity             668 non-null    int64
#  6   Cloudiness           668 non-null    int64
#  7   Wind Speed           668 non-null    float64
#  8   Current Description  668 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 47.1+ KB
